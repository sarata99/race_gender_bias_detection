# %%
'''
TF-IDF - Term Frequency - Inverse Data Frequency
    Term Frequency: frequency of the word in a document
    Inverse Data Frequency: used to calculatee the weight of rare words in the document
    i.e. rare words have a high IDF score
    
This notebook calculates the TF-IDF score for each word in a given message.
'''

import pandas as pd
import numpy as np
import string
import os

project_root = os.path.dirname(os.getcwd())
fall_18_data_path = project_root + '/Data/Fall_2018/'
fall_19_data_path = project_root + '/Data/Fall_2019/'
tfidf_path = project_root + '/tfidf/'

# %%
df_fall_18_messages = pd.read_excel(fall_18_data_path + 'FA18_messages_with_race_gender.xlsx', index_col=0)

# %%
df_fall_18_messages.head()
# Out:
#     User ID   Race Gender                                               Text
# 0  42683026  WHITE      F  Hey @Katie Poteet I know you said we should em...
# 1  25501571  WHITE      F  @Mary Cassell I would email Dr. K anyway with ...
# 2  42683026  WHITE      F  Ok, thanks a lot. I have the email typed but w...
# 3  25501571  WHITE      F                     Upstairs from our lecture hall
# 4  25501571  WHITE      F                                     Sherman 207!!!

# %%
# 2D array holding an array of words for each message
all_messages = []
# A set of all words used in all messages (no duplicates)
word_set = set()

for index, row in df_fall_18_messages.iterrows():
    message = row['Text'].split(" ")
    for i in range(len(message)):
        message[i] = message[i].translate(str.maketrans('', '', string.punctuation)).lower()
    word_set = set(word_set).union(set(message))
    all_messages.append(message)

# %%
# Array holding a dictionary of words for each message
# Dictionary consists of a word and its counts in the message (init to 0)
word_dicts = []
for message in all_messages:
    word_dicts.append(dict.fromkeys(word_set,0))

# %%
# Word dictionary for message 1 (counts initialized to 0)
word_dicts[0]
# Out:
# {'': 0,
#  'catmeif': 0,
#  'poorerless': 0,
#  '😂😂😂': 0,
#  'severe': 0,
#  'stacey’s': 0,
#  '125': 0,
#  'lollll': 0,
#  'order': 0,
#  'there\n': 0,
#  'basis': 0,
#  'stealing': 0,
#  'mrs': 0,
#  'stacys': 0,
#  'max': 0,
#  'spends': 0,
#  'amidst': 0,
#  'statementsean': 0,
#  'flat': 0,
#  'reserve': 0,
#  'induction': 0,
#  'uniqueness': 0,
#  'minimalist': 0,
#  'presemester': 0,
#  'alliance': 0,
#  'hard': 0,
#  'midterm': 0,
#  'portfolio': 0,
#  'moving': 0,
#  'from': 0,
#  'food\nwhat': 0,
#  '695': 0,
#  'garden': 0,
#  'wrong': 0,
#  'light': 0,
#  'kettle': 0,
#  'sec': 0,
#  'ballot': 0,
#  'plz': 0,
#  'around': 0,
#  'firearm': 0,
#  'itchange': 0,
#  'linked': 0,
#  'yep': 0,
#  'successful”\n\nclubs': 0,
#  'blown': 0,
#  '\njulie': 0,
#  '1215': 0,
#  'coordinated': 0,
#  'content': 0,
#  'anna': 0,
#  'preference': 0,
#  'divide': 0,
#  'grey': 0,
#  'initiatives': 0,
#  'today': 0,
#  'stood': 0,
#  'tomrooe': 0,
#  'prospective': 0,
#  'diabetes': 0,
#  'wheneverwherever': 0,
#  'taught': 0,
#  'oh': 0,
#  'gotcha': 0,
#  'violence': 0,
#  'naught': 0,
#  'start': 0,
#  'barring': 0,
#  'depends': 0,
#  'psych': 0,
#  '2\nnov': 0,
#  'oooooj': 0,
#  'hoo': 0,
#  'docked': 0,
#  'cheese': 0,
#  'docpresentation': 0,
#  'test': 0,
#  'ofknhow': 0,
#  'logistics': 0,
#  'lying': 0,
#  'creepier': 0,
#  'motivate': 0,
#  'rural': 0,
#  'titles': 0,
#  '5pm': 0,
#  '9\n\nthese': 0,
#  'as': 0,
#  '“sohei': 0,
#  'farming': 0,
#  'stores': 0,
#  'woof': 0,
#  'every': 0,
#  'killed': 0,
#  '\ndoes': 0,
#  '\nfaith': 0,
#  'prove': 0,
#  'decides': 0,
#  'inds': 0,
#  'shareemail': 0,
#  '👍': 0,
#  'heart': 0,
#  'announcement': 0,
#  'pizza': 0,
#  'looked': 0,
#  'patel': 0,
#  'lil': 0,
#  'stance': 0,
#  'gardens': 0,
#  'katie': 0,
#  'bella': 0,
#  'restaurant': 0,
#  'measured': 0,
#  'include': 0,
#  'mixed': 0,
#  '207': 0,
#  'total': 0,
#  'dressy': 0,
#  'need”': 0,
#  'supposed': 0,
#  'south': 0,
#  'timing': 0,
#  'interpretation': 0,
#  '\nfor': 0,
#  'senior': 0,
#  'links': 0,
#  '☺️': 0,
#  'locate': 0,
#  'donating': 0,
#  'size': 0,
#  'hrabowskis': 0,
#  'catch': 0,
#  'school\nmeade': 0,
#  'scared': 0,
#  'graduation': 0,
#  'funeral': 0,
#  'against': 0,
#  'everyone\ni': 0,
#  'arts': 0,
#  'mentioning': 0,
#  'additional': 0,
#  'days': 0,
#  'school\nriverview': 0,
#  'aid': 0,
#  'relevant': 0,
#  'guess': 0,
#  'yo': 0,
#  'advice': 0,
#  'graduating': 0,
#  'logistical': 0,
#  'saturn': 0,
#  'periods': 0,
#  'flannelsweater': 0,
#  'illness': 0,
#  'battle': 0,
#  'remind': 0,
#  'finally': 0,
#  'resumes': 0,
#  'others\nwe': 0,
#  'saying': 0,
#  'eons': 0,
#  'later': 0,
#  'sides': 0,
#  'hurt': 0,
#  'dedication': 0,
#  'visual': 0,
#  'hm': 0,
#  'attorney': 0,
#  'wanted\n\nquestion': 0,
#  'promptly': 0,
#  '😅': 0,
#  'refining': 0,
#  'normal': 0,
#  'bits': 0,
#  'looks': 0,
#  'team\ncan': 0,
#  'trinity': 0,
#  'he’s': 0,
#  'solid': 0,
#  'apple': 0,
#  'integrating': 0,
#  'revamping': 0,
#  '\nしーｊ\u3000\u3000\u3000°。': 0,
#  'books': 0,
#  'money': 0,
#  'diagram': 0,
#  'immediately': 0,
#  'wouldve': 0,
#  '“this': 0,
#  'httpsdocsgooglecomdocumentd1sdhxj0obplkcoip1tp9wuvvccb3zpishoqunvlzbj8': 0,
#  'partnerships': 0,
#  'maia’s': 0,
#  'decently': 0,
#  'derek': 0,
#  'necessarily': 0,
#  'pen': 0,
#  'bake': 0,
#  'attachment': 0,
#  'clubsorganizations': 0,
#  'harsh': 0,
#  'shut': 0,
#  'enjoyable': 0,
#  '\n\n4': 0,
#  'kitchens': 0,
#  'supporting': 0,
#  'bsos': 0,
#  'ya': 0,
#  'die': 0,
#  'unfortunately': 0,
#  'idk': 0,
#  'theyd': 0,
#  'moves': 0,
#  'il': 0,
#  'outoftheway': 0,
#  'need': 0,
#  'sike': 0,
#  'ahhhh': 0,
#  'aware': 0,
#  'formulate': 0,
#  'terms': 0,
#  'benkarans': 0,
#  'renaissance': 0,
#  'chinese': 0,
#  'dinner': 0,
#  'password': 0,
#  'schoolers': 0,
#  'natalie': 0,
#  'harder': 0,
#  'cards': 0,
#  'correctly': 0,
#  'ik': 0,
#  'asking': 0,
#  'introduction': 0,
#  'auditions': 0,
#  'sebastian’s': 0,
#  'paperbc': 0,
#  'nope': 0,
#  'quality': 0,
#  'crucial': 0,
#  'rewrote': 0,
#  'leader': 0,
#  'collaborate': 0,
#  'attention': 0,
#  '😊and': 0,
#  'pink': 0,
#  'adequate': 0,
#  '56': 0,
#  'sends': 0,
#  'pleased': 0,
#  'organizing': 0,
#  'powerpointnotes': 0,
#  'review': 0,
#  'tackle': 0,
#  'done': 0,
#  'frequently': 0,
#  'deletion': 0,
#  'httpssgroupmecomelftas': 0,
#  '78': 0,
#  'maia': 0,
#  'shoot': 0,
#  'delete': 0,
#  'discussing': 0,
#  'wellwritten': 0,
#  'membership': 0,
#  'seven': 0,
#  '😧': 0,
#  'pager': 0,
#  'keep': 0,
#  'squad': 0,
#  'transits': 0,
#  'sam': 0,
#  'caught': 0,
#  '“one': 0,
#  'associated': 0,
#  'cents': 0,
#  'outfits': 0,
#  'resubmit': 0,
#  'noonjust': 0,
#  'advisory': 0,
#  '15': 0,
#  'afford': 0,
#  '👏🏾👏🏾👏🏾': 0,
#  'care': 0,
#  'allpart': 0,
#  'always': 0,
#  'hire': 0,
#  'here': 0,
#  'counts': 0,
#  'famers': 0,
#  'based': 0,
#  '“to”': 0,
#  'picture': 0,
#  'shrimp': 0,
#  'gangs': 0,
#  'httpsdrivegooglecomaumbcedufiled1fxwpsyobr5sn86vb7k8asxacz94d5weuviewuspdrivesdk': 0,
#  'own': 0,
#  'ends': 0,
#  'wordier': 0,
#  'discussions': 0,
#  'proper': 0,
#  'powerpoint': 0,
#  'layman': 0,
#  'conference': 0,
#  'hook': 0,
#  'refined': 0,
#  'attack': 0,
#  'ones': 0,
#  'practices': 0,
#  'danke': 0,
#  'b': 0,
#  'mood': 0,
#  'do': 0,
#  'screencap': 0,
#  'sad': 0,
#  'glanced': 0,
#  'wdym': 0,
#  'nutrition': 0,
#  'doing': 0,
#  'wouldn’t': 0,
#  'podium': 0,
#  'partnering': 0,
#  'pile': 0,
#  'athletic': 0,
#  'about\ncommunity': 0,
#  'sirius\ni': 0,
#  'roughly': 0,
#  'remember': 0,
#  'general': 0,
#  'else': 0,
#  '9pm': 0,
#  'integrated': 0,
#  'fan': 0,
#  'shoes': 0,
#  'ecological': 0,
#  'north': 0,
#  'sex': 0,
#  'woodwork': 0,
#  'nightmare': 0,
#  'groceries': 0,
#  'wanted': 0,
#  'brother': 0,
#  'hotmood': 0,
#  '\ndress': 0,
#  'turtle': 0,
#  'studentevaluated': 0,
#  'combined': 0,
#  'buses': 0,
#  'health': 0,
#  'solutions': 0,
#  '\n\nalso': 0,
#  'rider': 0,
#  '10x': 0,
#  'life': 0,
#  'avenue': 0,
#  'bottoms': 0,
#  'built': 0,
#  'birthday': 0,
#  'passed': 0,
#  'saw': 0,
#  'interested—not': 0,
#  'twice': 0,
#  'all\ni': 0,
#  'up\ndr': 0,
#  'jobs': 0,
#  '😅😁”\ncharra': 0,
#  'they': 0,
#  'doesn’t': 0,
#  'somebody': 0,
#  'bsu': 0,
#  'chose': 0,
#  'career': 0,
#  'yip': 0,
#  'deficiencies': 0,
#  'multiparagraph': 0,
#  'syllabus': 0,
#  'causing': 0,
#  'leggings': 0,
#  'concern': 0,
#  'programs\n7': 0,
#  'leaving': 0,
#  'dip': 0,
#  'alternate': 0,
#  'prop': 0,
#  'joke': 0,
#  'home': 0,
#  'lost': 0,
#  'involving': 0,
#  'regular': 0,
#  '\none': 0,
#  'overview': 0,
#  'replies': 0,
#  'winners': 0,
#  'garner': 0,
#  'expenditures': 0,
#  'sierra': 0,
#  'active': 0,
#  'limitations': 0,
#  'wears': 0,
#  'hectic': 0,
#  'item': 0,
#  'diverse': 0,
#  'date': 0,
#  'capable': 0,
#  'where’s': 0,
#  'already': 0,
#  'vid': 0,
#  'httpstwittercomprofnearystatus1071058200307359744\n\nnatalie': 0,
#  'voicemail': 0,
#  'sean': 0,
#  'garnering': 0,
#  'hydroponics': 0,
#  'sending': 0,
#  'disenfranchised': 0,
#  'line': 0,
#  'overinsentivize': 0,
#  'unemployment': 0,
#  'afternoonevening': 0,
#  'completion': 0,
#  'sexed': 0,
#  'voice': 0,
#  'indication': 0,
#  'afternoons': 0,
#  '31': 0,
#  'stronger': 0,
#  'rely': 0,
#  'peter': 0,
#  'spending': 0,
#  'dove”': 0,
#  'clip': 0,
#  'premed': 0,
#  'maximization': 0,
#  'apply': 0,
#  'some': 0,
#  'grocery': 0,
#  'talented': 0,
#  'allman': 0,
#  'asthma': 0,
#  'yup': 0,
#  'baltimore': 0,
#  'becomes': 0,
#  'ignorantly': 0,
#  'diseases': 0,
#  'victim': 0,
#  'definitively': 0,
#  'transitioning': 0,
#  'accountable': 0,
#  'meaningful': 0,
#  'that👏🏾': 0,
#  'wider': 0,
#  '26': 0,
#  'contribute': 0,
#  'sometime': 0,
#  'rather': 0,
#  'interests': 0,
#  'reaching': 0,
#  'ms': 0,
#  'telling': 0,
#  '‘brief’': 0,
#  'however': 0,
#  '16th': 0,
#  'lot': 0,
#  'vibe': 0,
#  'seventh': 0,
#  'toppings': 0,
#  'facts': 0,
#  'particulars': 0,
#  'ever': 0,
#  'decide': 0,
#  '“the': 0,
#  'opportunities\xa0': 0,
#  'close': 0,
#  'theater': 0,
#  'number': 0,
#  '\n∧＿∧': 0,
#  'directory': 0,
#  'twists': 0,
#  'communities': 0,
#  'defined': 0,
#  'program': 0,
#  'end': 0,
#  'procrastinate': 0,
#  'entirely': 0,
#  'pimlico': 0,
#  'mildly': 0,
#  '6th': 0,
#  'rebecca': 0,
#  'cry': 0,
#  '615': 0,
#  'obviously': 0,
#  'nowm': 0,
#  'young': 0,
#  'google': 0,
#  'viewing': 0,
#  'scholars': 0,
#  'plants': 0,
#  'accident': 0,
#  'applied': 0,
#  'yaaa': 0,
#  'cat”': 0,
#  'numbers': 0,
#  'attend': 0,
#  'nobody': 0,
#  'meetings': 0,
#  'year': 0,
#  'judge': 0,
#  'families': 0,
#  'gotta': 0,
#  'messages': 0,
#  'chronic': 0,
#  'said': 0,
#  'say': 0,
#  'department': 0,
#  'wordnh': 0,
#  'she': 0,
#  'hi': 0,
#  'conflict': 0,
#  'fit': 0,
#  'meetup': 0,
#  'brenner': 0,
#  'program\nhow': 0,
#  'play': 0,
#  'httpwwwbbccouknewsworlduscanada45749891\nthis': 0,
#  'tiny': 0,
#  'rey': 0,
#  'exam': 0,
#  'fix': 0,
#  'belcher': 0,
#  'proceed': 0,
#  'apparently': 0,
#  'tho': 0,
#  'samyukta': 0,
#  'heyy': 0,
#  'cringey': 0,
#  'objective': 0,
#  'ed': 0,
#  'calcs': 0,
#  'different': 0,
#  'httpsgristfileswordpresscom201008baltimorecityfoodpolicytaskforcereportpdf': 0,
#  'september': 0,
#  'go': 0,
#  'debate': 0,
#  'happen': 0,
#  'visiting': 0,
#  'mon': 0,
#  'incentiveway': 0,
#  'lacking': 0,
#  'morgan': 0,
#  'baltimorian': 0,
#  'prize': 0,
#  'meetchat': 0,
#  'which': 0,
#  'comparable': 0,
#  'pain': 0,
#  'laugh': 0,
#  'you’re': 0,
#  '😢': 0,
#  'won': 0,
#  'fleshed': 0,
#  'julias': 0,
#  'shrink': 0,
#  'potentially': 0,
#  'chart': 0,
#  'acknowledgement': 0,
#  'critique': 0,
#  'street': 0,
#  'again': 0,
#  'seems': 0,
#  'sentances': 0,
#  'idc': 0,
#  'produce': 0,
#  'overreaching': 0,
#  'daun': 0,
#  'nonperishable': 0,
#  'confused': 0,
#  'crack': 0,
#  'nobodys': 0,
#  'impressive': 0,
#  'routewhosenamechanged': 0,
#  'opinions': 0,
#  'finishing': 0,
#  'believe': 0,
#  'answered': 0,
#  'reminders': 0,
#  'everywhere': 0,
#  'announced': 0,
#  'market': 0,
#  'unmute': 0,
#  'showing': 0,
#  'httpswwwwhen2meetcom7607008zo7av\n': 0,
#  'opens': 0,
#  'thursday': 0,
#  'medina': 0,
#  'bell’s': 0,
#  '275': 0,
#  'wifi': 0,
#  'generate': 0,
#  'days\n\nyou': 0,
#  'veto': 0,
#  'they’ll': 0,
#  'pages': 0,
#  'overachievers': 0,
#  'impact': 0,
#  'uh': 0,
#  'box': 0,
#  'raise': 0,
#  'swathi': 0,
#  '1416': 0,
#  'sooner': 0,
#  'swim': 0,
#  'engaging': 0,
#  'winging': 0,
#  'superheroes': 0,
#  '\n\nstatistic': 0,
#  'sign': 0,
#  'mail': 0,
#  'answering': 0,
#  'yeahh': 0,
#  'prompt': 0,
#  'everybody': 0,
#  'standards': 0,
#  'suspended': 0,
#  'responding': 0,
#  '1130130': 0,
#  'ranting': 0,
#  'educating': 0,
#  'healthy': 0,
#  'summarized': 0,
#  '😞': 0,
#  'obstacle': 0,
#  'mentor': 0,
#  'growth': 0,
#  'karan': 0,
#  'stove': 0,
#  'claiming': 0,
#  'brainstorming': 0,
#  'judgment': 0,
#  '1000': 0,
#  'leaders': 0,
#  'respond': 0,
#  'implying': 0,
#  'regards': 0,
#  'defines': 0,
#  'style': 0,
#  'matter': 0,
#  'sustained': 0,
#  'soonish': 0,
#  'cabinets': 0,
#  'drop': 0,
#  'rock': 0,
#  'ノ': 0,
#  'interrupt': 0,
#  'spot': 0,
#  'ice': 0,
#  'baby': 0,
#  'distance': 0,
#  'budgetingget': 0,
#  'shannon': 0,
#  'president': 0,
#  'putting': 0,
#  'crowded\nex': 0,
#  'meh': 0,
#  '29th': 0,
#  'uber': 0,
#  'honestly': 0,
#  'musgrove': 0,
#  'dozens': 0,
#  'considered': 0,
#  '1010': 0,
#  'pulled': 0,
#  'finalize': 0,
#  'fare': 0,
#  'supplied': 0,
#  'phoneslaptop': 0,
#  '😆': 0,
#  'schoolcollege': 0,
#  'ride': 0,
#  'panic': 0,
#  'closed': 0,
#  'downstairs': 0,
#  'was': 0,
#  'fundraise': 0,
#  '71\xa0': 0,
#  'team\nreminder': 0,
#  'meanings': 0,
#  '1150': 0,
#  'signup': 0,
#  'sue': 0,
#  'besides': 0,
#  'slightly': 0,
#  'diminish': 0,
#  'blurp': 0,
#  'plausible': 0,
#  'winner': 0,
#  'bates': 0,
#  'respect': 0,
#  'awesome': 0,
#  'meas': 0,
#  'stretch': 0,
#  'potter': 0,
#  'eye': 0,
#  'wrapped': 0,
#  'tmrw': 0,
#  'maximum': 0,
#  '34pm': 0,
#  'convenient': 0,
#  'messaged': 0,
#  'middle': 0,
#  'philanthropic': 0,
#  'pieces': 0,
#  'trust': 0,
#  'break😆': 0,
#  'tried': 0,
#  'coach': 0,
#  'serious': 0,
#  'tax': 0,
#  'characterstics': 0,
#  'professor': 0,
#  'httpswwwcdcgovpcdissues2012110222htm': 0,
#  'nighter': 0,
#  'u': 0,
#  'nj': 0,
#  '6101': 0,
#  'wondering': 0,
#  '♥️': 0,
#  'turned': 0,
#  'httpsdocsgooglecomdocumentd16c4jyjnsbcqidxar9b28bakwccln0yb9x8z4wuwr34edituspsharing': 0,
#  '“fuck': 0,
#  'various': 0,
#  'living': 0,
#  'appointment': 0,
#  'jst': 0,
#  'clothes': 0,
#  'im': 0,
#  'drag': 0,
#  'increasing': 0,
#  'cheasapeake': 0,
#  'cooperation': 0,
#  'probs': 0,
#  'length': 0,
#  'hoco': 0,
#  'impulse”': 0,
#  'charra': 0,
#  '\nduring': 0,
#  'movies': 0,
#  'vegetarianveganlactose': 0,
#  'therefore': 0,
#  'approaches': 0,
#  'section': 0,
#  'flaw': 0,
#  'placement': 0,
#  'fuck': 0,
#  'hes': 0,
#  'amendment': 0,
#  'define': 0,
#  'subculture': 0,
#  'soo': 0,
#  'black': 0,
#  'homeless': 0,
#  'hear': 0,
#  'temperature': 0,
#  'abt': 0,
#  'school\nben': 0,
#  'throw': 0,
#  'pressure': 0,
#  'slight': 0,
#  'forever': 0,
#  'swimmers': 0,
#  'setting': 0,
#  '“5': 0,
#  'evening': 0,
#  'that’s': 0,
#  'kchong2umbcedu': 0,
#  'completely': 0,
#  '4': 0,
#  'here’s': 0,
#  'helps': 0,
#  'same': 0,
#  'logged': 0,
#  'compiled': 0,
#  'swear': 0,
#  'it😇': 0,
#  'input': 0,
#  '23': 0,
#  'enjoyed': 0,
#  'laptops': 0,
#  'orioles': 0,
#  'deleted': 0,
#  'part\n3': 0,
#  'interdisciplinary': 0,
#  '😎': 0,
#  'school': 0,
#  'reliable': 0,
#  '☹': 0,
#  'tiebreaker': 0,
#  'individualbased': 0,
#  'speaking': 0,
#  'it”': 0,
#  'meantime': 0,
#  'environments': 0,
#  'operators': 0,
#  'hop': 0,
#  'transportation': 0,
#  'interested': 0,
#  '215530': 0,
#  'refurbishment': 0,
#  'deals': 0,
#  'alright': 0,
#  'incentives': 0,
#  'bit”': 0,
#  'in\xa0': 0,
#  'grade': 0,
#  'excellence': 0,
#  'poor': 0,
#  'thirty': 0,
#  'drivers': 0,
#  'facet': 0,
#  'ups': 0,
#  'vegan': 0,
#  'via': 0,
#  'welcome': 0,
#  '1210': 0,
#  'nic': 0,
#  'idea': 0,
#  'ideally': 0,
#  'missing': 0,
#  'shortly': 0,
#  'tied': 0,
#  'surveys': 0,
#  'lowkey': 0,
#  'pdf': 0,
#  'up\n\ngetting': 0,
#  'tonight': 0,
#  'commitment—to': 0,
#  'join\n\nhttpsgroupmecomjoingroup45563234qjc2pk': 0,
#  'fast': 0,
#  '3pm': 0,
#  'brigade': 0,
#  'counselor': 0,
#  'agenda': 0,
#  'warrant': 0,
#  'commitments': 0,
#  'trucklobbying': 0,
#  '515': 0,
#  'pasted': 0,
#  'commuting': 0,
#  'join': 0,
#  'social': 0,
#  'ahead': 0,
#  'research': 0,
#  'timewhere': 0,
#  'oconnor': 0,
#  'qualifications': 0,
#  'way': 0,
#  'states': 0,
#  'stay': 0,
#  'treating': 0,
#  'desert”': 0,
#  'logic': 0,
#  'rescheduled': 0,
#  'scheduling': 0,
#  'erin°': 0,
#  'facing': 0,
#  '111': 0,
#  'orion': 0,
#  'dust': 0,
#  '220': 0,
#  'assistance': 0,
#  'toc': 0,
#  'topic': 0,
#  'judges’': 0,
#  'able': 0,
#  '9th': 0,
#  'the': 0,
#  'niw': 0,
#  'comment': 0,
#  'james': 0,
#  'audience': 0,
#  'spoken': 0,
#  '4730': 0,
#  'medicaid': 0,
#  'offic': 0,
#  '\nwe': 0,
#  'motivation': 0,
#  'proposed': 0,
#  'outcome': 0,
#  '205': 0,
#  'amd': 0,
#  'pickup': 0,
#  'speech': 0,
#  'useful': 0,
#  'theo': 0,
#  'assist': 0,
#  'pins': 0,
#  'starting': 0,
#  'funding': 0,
#  '100': 0,
#  'restrictions': 0,
#  'valid': 0,
#  'reserved': 0,
#  'wordy': 0,
#  'stats': 0,
#  'miss': 0,
#  '7th': 0,
#  'corrected': 0,
#  'ches': 0,
#  '1159pm': 0,
#  'brigades': 0,
#  '👍🏻': 0,
#  'youve': 0,
#  'gillian': 0,
#  'guessed': 0,
#  'poll': 0,
#  'tbh': 0,
#  'succeed': 0,
#  'donated': 0,
#  'blueprintwhat’s': 0,
#  'deal': 0,
#  'bon': 0,
#  'apron': 0,
#  'stupid': 0,
#  'later\n\nhaving': 0,
#  'seattle': 0,
#  'essays': 0,
#  'second': 0,
#  'eat': 0,
#  'accounts': 0,
#  'essentially': 0,
#  'inclusion': 0,
#  'teaches': 0,
#  'blueprint': 0,
#  'rationale': 0,
#  'growing': 0,
#  'dollars': 0,
#  'bonjour': 0,
#  'picky': 0,
#  'difficulty': 0,
#  'launch': 0,
#  'm': 0,
#  'routine': 0,
#  'mile': 0,
#  'ethics': 0,
#  'wind': 0,
#  'jumping': 0,
#  'provides': 0,
#  'actually': 0,
#  'deadlines': 0,
#  'httpssgroupmecomcpcotye': 0,
#  'transit': 0,
#  'images': 0,
#  'disease': 0,
#  'can': 0,
#  '2430': 0,
#  'policy': 0,
#  'smcnary1umbcedu': 0,
#  'create': 0,
#  'many': 0,
#  'they’re': 0,
#  'follows': 0,
#  'inform': 0,
#  'crank': 0,
#  'garnett': 0,
#  'whoever’s': 0,
#  'improving': 0,
#  'dhall': 0,
#  'owens': 0,
#  'alcohol': 0,
#  'provide': 0,
#  'must': 0,
#  'cannot': 0,
#  'side': 0,
#  'identical': 0,
#  'passes': 0,
#  'choice': 0,
#  'closing': 0,
#  'dc': 0,
#  'lunches': 0,
#  'skinny': 0,
#  'compilation': 0,
#  'graduate': 0,
#  'whoever': 0,
#  'feasible': 0,
#  'longue': 0,
#  'lactoseintolerant': 0,
#  'first': 0,
#  'k’s': 0,
#  'homes': 0,
#  'impactful': 0,
#  'working': 0,
#  'cares': 0,
#  'reserving': 0,
#  'midnight': 0,
#  'highschool': 0,
#  'limit': 0,
#  'easy': 0,
#  'interview': 0,
#  'tangible': 0,
#  'regroup': 0,
#  'problem': 0,
#  'apartment': 0,
#  'team\nsorry': 0,
#  'vp': 0,
#  ...}

# %%
# Add counts of each word in a message to it's dictionary
for i in range(len(all_messages)):
    for word in all_messages[i]:
        word_dicts[i][word] += 1

# %%
# Word dictionary for message 1 (some counts are now non-zero)
print(word_dicts[0])
# Out:
# {'': 0, 'catmeif': 0, 'poorerless': 0, '😂😂😂': 0, 'severe': 0, 'stacey’s': 0, '125': 0, 'lollll': 0, 'order': 0, 'there\n': 0, 'basis': 0, 'stealing': 0, 'mrs': 0, 'stacys': 0, 'max': 0, 'spends': 0, 'amidst': 0, 'statementsean': 0, 'flat': 0, 'reserve': 0, 'induction': 0, 'uniqueness': 0, 'minimalist': 0, 'presemester': 0, 'alliance': 0, 'hard': 0, 'midterm': 0, 'portfolio': 0, 'moving': 0, 'from': 0, 'food\nwhat': 0, '695': 0, 'garden': 0, 'wrong': 0, 'light': 0, 'kettle': 0, 'sec': 0, 'ballot': 0, 'plz': 0, 'around': 0, 'firearm': 0, 'itchange': 0, 'linked': 0, 'yep': 0, 'successful”\n\nclubs': 0, 'blown': 0, '\njulie': 0, '1215': 0, 'coordinated': 0, 'content': 0, 'anna': 0, 'preference': 0, 'divide': 0, 'grey': 0, 'initiatives': 0, 'today': 0, 'stood': 0, 'tomrooe': 0, 'prospective': 0, 'diabetes': 0, 'wheneverwherever': 0, 'taught': 0, 'oh': 0, 'gotcha': 0, 'violence': 0, 'naught': 0, 'start': 0, 'barring': 0, 'depends': 0, 'psych': 0, '2\nnov': 0, 'oooooj': 0, 'hoo': 0, 'docked': 0, 'cheese': 0, 'docpresentation': 0, 'test': 0, 'ofknhow': 0, 'logistics': 0, 'lying': 0, 'creepier': 0, 'motivate': 0, 'rural': 0, 'titles': 0, '5pm': 0, '9\n\nthese': 0, 'as': 0, '“sohei': 0, 'farming': 0, 'stores': 0, 'woof': 0, 'every': 0, 'killed': 0, '\ndoes': 0, '\nfaith': 0, 'prove': 0, 'decides': 0, 'inds': 0, 'shareemail': 0, '👍': 0, 'heart': 0, 'announcement': 0, 'pizza': 0, 'looked': 0, 'patel': 0, 'lil': 0, 'stance': 0, 'gardens': 0, 'katie': 1, 'bella': 0, 'restaurant': 0, 'measured': 0, 'include': 0, 'mixed': 0, '207': 0, 'total': 0, 'dressy': 0, 'need”': 0, 'supposed': 0, 'south': 0, 'timing': 0, 'interpretation': 0, '\nfor': 0, 'senior': 0, 'links': 0, '☺️': 0, 'locate': 0, 'donating': 0, 'size': 0, 'hrabowskis': 0, 'catch': 0, 'school\nmeade': 0, 'scared': 0, 'graduation': 0, 'funeral': 0, 'against': 0, 'everyone\ni': 0, 'arts': 0, 'mentioning': 0, 'additional': 0, 'days': 0, 'school\nriverview': 0, 'aid': 0, 'relevant': 0, 'guess': 0, 'yo': 0, 'advice': 0, 'graduating': 0, 'logistical': 0, 'saturn': 0, 'periods': 0, 'flannelsweater': 0, 'illness': 0, 'battle': 0, 'remind': 0, 'finally': 0, 'resumes': 0, 'others\nwe': 0, 'saying': 0, 'eons': 0, 'later': 0, 'sides': 0, 'hurt': 0, 'dedication': 0, 'visual': 0, 'hm': 0, 'attorney': 0, 'wanted\n\nquestion': 0, 'promptly': 0, '😅': 0, 'refining': 0, 'normal': 0, 'bits': 0, 'looks': 0, 'team\ncan': 0, 'trinity': 0, 'he’s': 0, 'solid': 0, 'apple': 0, 'integrating': 0, 'revamping': 0, '\nしーｊ\u3000\u3000\u3000°。': 0, 'books': 0, 'money': 0, 'diagram': 0, 'immediately': 0, 'wouldve': 0, '“this': 0, 'httpsdocsgooglecomdocumentd1sdhxj0obplkcoip1tp9wuvvccb3zpishoqunvlzbj8': 0, 'partnerships': 0, 'maia’s': 0, 'decently': 0, 'derek': 0, 'necessarily': 0, 'pen': 0, 'bake': 0, 'attachment': 0, 'clubsorganizations': 0, 'harsh': 0, 'shut': 0, 'enjoyable': 0, '\n\n4': 0, 'kitchens': 0, 'supporting': 0, 'bsos': 0, 'ya': 0, 'die': 0, 'unfortunately': 0, 'idk': 1, 'theyd': 0, 'moves': 0, 'il': 0, 'outoftheway': 0, 'need': 0, 'sike': 0, 'ahhhh': 0, 'aware': 0, 'formulate': 0, 'terms': 0, 'benkarans': 0, 'renaissance': 0, 'chinese': 0, 'dinner': 0, 'password': 0, 'schoolers': 0, 'natalie': 0, 'harder': 0, 'cards': 0, 'correctly': 0, 'ik': 0, 'asking': 0, 'introduction': 0, 'auditions': 0, 'sebastian’s': 0, 'paperbc': 0, 'nope': 0, 'quality': 0, 'crucial': 0, 'rewrote': 0, 'leader': 0, 'collaborate': 0, 'attention': 0, '😊and': 0, 'pink': 0, 'adequate': 0, '56': 0, 'sends': 0, 'pleased': 0, 'organizing': 0, 'powerpointnotes': 0, 'review': 0, 'tackle': 0, 'done': 0, 'frequently': 0, 'deletion': 0, 'httpssgroupmecomelftas': 0, '78': 0, 'maia': 0, 'shoot': 0, 'delete': 0, 'discussing': 0, 'wellwritten': 0, 'membership': 0, 'seven': 0, '😧': 0, 'pager': 0, 'keep': 0, 'squad': 0, 'transits': 0, 'sam': 0, 'caught': 0, '“one': 0, 'associated': 0, 'cents': 0, 'outfits': 0, 'resubmit': 0, 'noonjust': 0, 'advisory': 0, '15': 0, 'afford': 0, '👏🏾👏🏾👏🏾': 0, 'care': 0, 'allpart': 0, 'always': 0, 'hire': 0, 'here': 0, 'c ...

# %%
'''
df_word_counts = pd.DataFrame(word_dicts)
counter = 0
for dictionary in word_dicts:
    print(all_messages[counter])
    for i in dictionary:
        if (dictionary[i] >= 1):
            print(dictionary[i])
    counter += 1
'''
# Out:
# '\ndf_word_counts = pd.DataFrame(word_dicts)\ncounter = 0\nfor dictionary in word_dicts:\n    print(all_messages[counter])\n    for i in dictionary:\n        if (dictionary[i] >= 1):\n            print(dictionary[i])\n    counter += 1\n'

# %%
#df_word_counts.to_excel(tfidf_path+"FA18_word_count_vectors.xlsx")

# %%
# Compute term frequency
def computeTF(wordDict, bagOfWords):
    tfDict = {}
    bagOfWordsCount = len(bagOfWords)
    for word, count in wordDict.items():
        tfDict[word] = count / float(bagOfWordsCount)
    return tfDict

# %%
word_dict_tf = []

# %%
for index, row in df_fall_18_messages.iterrows():
    word_dict_tf.append(computeTF(word_dicts[index], all_messages[index]))

# %%
word_dict_tf[0]
# Out:
# {'': 0.0,
#  'catmeif': 0.0,
#  'poorerless': 0.0,
#  '😂😂😂': 0.0,
#  'severe': 0.0,
#  'stacey’s': 0.0,
#  '125': 0.0,
#  'lollll': 0.0,
#  'order': 0.0,
#  'there\n': 0.0,
#  'basis': 0.0,
#  'stealing': 0.0,
#  'mrs': 0.0,
#  'stacys': 0.0,
#  'max': 0.0,
#  'spends': 0.0,
#  'amidst': 0.0,
#  'statementsean': 0.0,
#  'flat': 0.0,
#  'reserve': 0.0,
#  'induction': 0.0,
#  'uniqueness': 0.0,
#  'minimalist': 0.0,
#  'presemester': 0.0,
#  'alliance': 0.0,
#  'hard': 0.0,
#  'midterm': 0.0,
#  'portfolio': 0.0,
#  'moving': 0.0,
#  'from': 0.0,
#  'food\nwhat': 0.0,
#  '695': 0.0,
#  'garden': 0.0,
#  'wrong': 0.0,
#  'light': 0.0,
#  'kettle': 0.0,
#  'sec': 0.0,
#  'ballot': 0.0,
#  'plz': 0.0,
#  'around': 0.0,
#  'firearm': 0.0,
#  'itchange': 0.0,
#  'linked': 0.0,
#  'yep': 0.0,
#  'successful”\n\nclubs': 0.0,
#  'blown': 0.0,
#  '\njulie': 0.0,
#  '1215': 0.0,
#  'coordinated': 0.0,
#  'content': 0.0,
#  'anna': 0.0,
#  'preference': 0.0,
#  'divide': 0.0,
#  'grey': 0.0,
#  'initiatives': 0.0,
#  'today': 0.0,
#  'stood': 0.0,
#  'tomrooe': 0.0,
#  'prospective': 0.0,
#  'diabetes': 0.0,
#  'wheneverwherever': 0.0,
#  'taught': 0.0,
#  'oh': 0.0,
#  'gotcha': 0.0,
#  'violence': 0.0,
#  'naught': 0.0,
#  'start': 0.0,
#  'barring': 0.0,
#  'depends': 0.0,
#  'psych': 0.0,
#  '2\nnov': 0.0,
#  'oooooj': 0.0,
#  'hoo': 0.0,
#  'docked': 0.0,
#  'cheese': 0.0,
#  'docpresentation': 0.0,
#  'test': 0.0,
#  'ofknhow': 0.0,
#  'logistics': 0.0,
#  'lying': 0.0,
#  'creepier': 0.0,
#  'motivate': 0.0,
#  'rural': 0.0,
#  'titles': 0.0,
#  '5pm': 0.0,
#  '9\n\nthese': 0.0,
#  'as': 0.0,
#  '“sohei': 0.0,
#  'farming': 0.0,
#  'stores': 0.0,
#  'woof': 0.0,
#  'every': 0.0,
#  'killed': 0.0,
#  '\ndoes': 0.0,
#  '\nfaith': 0.0,
#  'prove': 0.0,
#  'decides': 0.0,
#  'inds': 0.0,
#  'shareemail': 0.0,
#  '👍': 0.0,
#  'heart': 0.0,
#  'announcement': 0.0,
#  'pizza': 0.0,
#  'looked': 0.0,
#  'patel': 0.0,
#  'lil': 0.0,
#  'stance': 0.0,
#  'gardens': 0.0,
#  'katie': 0.015873015873015872,
#  'bella': 0.0,
#  'restaurant': 0.0,
#  'measured': 0.0,
#  'include': 0.0,
#  'mixed': 0.0,
#  '207': 0.0,
#  'total': 0.0,
#  'dressy': 0.0,
#  'need”': 0.0,
#  'supposed': 0.0,
#  'south': 0.0,
#  'timing': 0.0,
#  'interpretation': 0.0,
#  '\nfor': 0.0,
#  'senior': 0.0,
#  'links': 0.0,
#  '☺️': 0.0,
#  'locate': 0.0,
#  'donating': 0.0,
#  'size': 0.0,
#  'hrabowskis': 0.0,
#  'catch': 0.0,
#  'school\nmeade': 0.0,
#  'scared': 0.0,
#  'graduation': 0.0,
#  'funeral': 0.0,
#  'against': 0.0,
#  'everyone\ni': 0.0,
#  'arts': 0.0,
#  'mentioning': 0.0,
#  'additional': 0.0,
#  'days': 0.0,
#  'school\nriverview': 0.0,
#  'aid': 0.0,
#  'relevant': 0.0,
#  'guess': 0.0,
#  'yo': 0.0,
#  'advice': 0.0,
#  'graduating': 0.0,
#  'logistical': 0.0,
#  'saturn': 0.0,
#  'periods': 0.0,
#  'flannelsweater': 0.0,
#  'illness': 0.0,
#  'battle': 0.0,
#  'remind': 0.0,
#  'finally': 0.0,
#  'resumes': 0.0,
#  'others\nwe': 0.0,
#  'saying': 0.0,
#  'eons': 0.0,
#  'later': 0.0,
#  'sides': 0.0,
#  'hurt': 0.0,
#  'dedication': 0.0,
#  'visual': 0.0,
#  'hm': 0.0,
#  'attorney': 0.0,
#  'wanted\n\nquestion': 0.0,
#  'promptly': 0.0,
#  '😅': 0.0,
#  'refining': 0.0,
#  'normal': 0.0,
#  'bits': 0.0,
#  'looks': 0.0,
#  'team\ncan': 0.0,
#  'trinity': 0.0,
#  'he’s': 0.0,
#  'solid': 0.0,
#  'apple': 0.0,
#  'integrating': 0.0,
#  'revamping': 0.0,
#  '\nしーｊ\u3000\u3000\u3000°。': 0.0,
#  'books': 0.0,
#  'money': 0.0,
#  'diagram': 0.0,
#  'immediately': 0.0,
#  'wouldve': 0.0,
#  '“this': 0.0,
#  'httpsdocsgooglecomdocumentd1sdhxj0obplkcoip1tp9wuvvccb3zpishoqunvlzbj8': 0.0,
#  'partnerships': 0.0,
#  'maia’s': 0.0,
#  'decently': 0.0,
#  'derek': 0.0,
#  'necessarily': 0.0,
#  'pen': 0.0,
#  'bake': 0.0,
#  'attachment': 0.0,
#  'clubsorganizations': 0.0,
#  'harsh': 0.0,
#  'shut': 0.0,
#  'enjoyable': 0.0,
#  '\n\n4': 0.0,
#  'kitchens': 0.0,
#  'supporting': 0.0,
#  'bsos': 0.0,
#  'ya': 0.0,
#  'die': 0.0,
#  'unfortunately': 0.0,
#  'idk': 0.015873015873015872,
#  'theyd': 0.0,
#  'moves': 0.0,
#  'il': 0.0,
#  'outoftheway': 0.0,
#  'need': 0.0,
#  'sike': 0.0,
#  'ahhhh': 0.0,
#  'aware': 0.0,
#  'formulate': 0.0,
#  'terms': 0.0,
#  'benkarans': 0.0,
#  'renaissance': 0.0,
#  'chinese': 0.0,
#  'dinner': 0.0,
#  'password': 0.0,
#  'schoolers': 0.0,
#  'natalie': 0.0,
#  'harder': 0.0,
#  'cards': 0.0,
#  'correctly': 0.0,
#  'ik': 0.0,
#  'asking': 0.0,
#  'introduction': 0.0,
#  'auditions': 0.0,
#  'sebastian’s': 0.0,
#  'paperbc': 0.0,
#  'nope': 0.0,
#  'quality': 0.0,
#  'crucial': 0.0,
#  'rewrote': 0.0,
#  'leader': 0.0,
#  'collaborate': 0.0,
#  'attention': 0.0,
#  '😊and': 0.0,
#  'pink': 0.0,
#  'adequate': 0.0,
#  '56': 0.0,
#  'sends': 0.0,
#  'pleased': 0.0,
#  'organizing': 0.0,
#  'powerpointnotes': 0.0,
#  'review': 0.0,
#  'tackle': 0.0,
#  'done': 0.0,
#  'frequently': 0.0,
#  'deletion': 0.0,
#  'httpssgroupmecomelftas': 0.0,
#  '78': 0.0,
#  'maia': 0.0,
#  'shoot': 0.0,
#  'delete': 0.0,
#  'discussing': 0.0,
#  'wellwritten': 0.0,
#  'membership': 0.0,
#  'seven': 0.0,
#  '😧': 0.0,
#  'pager': 0.0,
#  'keep': 0.0,
#  'squad': 0.0,
#  'transits': 0.0,
#  'sam': 0.0,
#  'caught': 0.0,
#  '“one': 0.0,
#  'associated': 0.0,
#  'cents': 0.0,
#  'outfits': 0.0,
#  'resubmit': 0.0,
#  'noonjust': 0.0,
#  'advisory': 0.0,
#  '15': 0.0,
#  'afford': 0.0,
#  '👏🏾👏🏾👏🏾': 0.0,
#  'care': 0.0,
#  'allpart': 0.0,
#  'always': 0.0,
#  'hire': 0.0,
#  'here': 0.0,
#  'counts': 0.0,
#  'famers': 0.0,
#  'based': 0.0,
#  '“to”': 0.0,
#  'picture': 0.0,
#  'shrimp': 0.0,
#  'gangs': 0.0,
#  'httpsdrivegooglecomaumbcedufiled1fxwpsyobr5sn86vb7k8asxacz94d5weuviewuspdrivesdk': 0.0,
#  'own': 0.0,
#  'ends': 0.0,
#  'wordier': 0.0,
#  'discussions': 0.0,
#  'proper': 0.0,
#  'powerpoint': 0.0,
#  'layman': 0.0,
#  'conference': 0.0,
#  'hook': 0.0,
#  'refined': 0.0,
#  'attack': 0.0,
#  'ones': 0.0,
#  'practices': 0.0,
#  'danke': 0.0,
#  'b': 0.0,
#  'mood': 0.0,
#  'do': 0.047619047619047616,
#  'screencap': 0.0,
#  'sad': 0.0,
#  'glanced': 0.0,
#  'wdym': 0.0,
#  'nutrition': 0.0,
#  'doing': 0.0,
#  'wouldn’t': 0.0,
#  'podium': 0.0,
#  'partnering': 0.0,
#  'pile': 0.0,
#  'athletic': 0.0,
#  'about\ncommunity': 0.0,
#  'sirius\ni': 0.0,
#  'roughly': 0.0,
#  'remember': 0.0,
#  'general': 0.0,
#  'else': 0.0,
#  '9pm': 0.0,
#  'integrated': 0.0,
#  'fan': 0.0,
#  'shoes': 0.0,
#  'ecological': 0.0,
#  'north': 0.0,
#  'sex': 0.0,
#  'woodwork': 0.0,
#  'nightmare': 0.0,
#  'groceries': 0.0,
#  'wanted': 0.015873015873015872,
#  'brother': 0.0,
#  'hotmood': 0.0,
#  '\ndress': 0.0,
#  'turtle': 0.0,
#  'studentevaluated': 0.0,
#  'combined': 0.0,
#  'buses': 0.0,
#  'health': 0.0,
#  'solutions': 0.0,
#  '\n\nalso': 0.0,
#  'rider': 0.0,
#  '10x': 0.0,
#  'life': 0.0,
#  'avenue': 0.0,
#  'bottoms': 0.0,
#  'built': 0.0,
#  'birthday': 0.0,
#  'passed': 0.0,
#  'saw': 0.0,
#  'interested—not': 0.0,
#  'twice': 0.0,
#  'all\ni': 0.0,
#  'up\ndr': 0.0,
#  'jobs': 0.0,
#  '😅😁”\ncharra': 0.0,
#  'they': 0.0,
#  'doesn’t': 0.0,
#  'somebody': 0.0,
#  'bsu': 0.0,
#  'chose': 0.0,
#  'career': 0.0,
#  'yip': 0.0,
#  'deficiencies': 0.0,
#  'multiparagraph': 0.0,
#  'syllabus': 0.0,
#  'causing': 0.0,
#  'leggings': 0.0,
#  'concern': 0.0,
#  'programs\n7': 0.0,
#  'leaving': 0.0,
#  'dip': 0.0,
#  'alternate': 0.0,
#  'prop': 0.0,
#  'joke': 0.0,
#  'home': 0.0,
#  'lost': 0.0,
#  'involving': 0.0,
#  'regular': 0.0,
#  '\none': 0.0,
#  'overview': 0.0,
#  'replies': 0.0,
#  'winners': 0.0,
#  'garner': 0.0,
#  'expenditures': 0.0,
#  'sierra': 0.0,
#  'active': 0.0,
#  'limitations': 0.0,
#  'wears': 0.0,
#  'hectic': 0.0,
#  'item': 0.0,
#  'diverse': 0.0,
#  'date': 0.031746031746031744,
#  'capable': 0.0,
#  'where’s': 0.0,
#  'already': 0.0,
#  'vid': 0.0,
#  'httpstwittercomprofnearystatus1071058200307359744\n\nnatalie': 0.0,
#  'voicemail': 0.0,
#  'sean': 0.0,
#  'garnering': 0.0,
#  'hydroponics': 0.0,
#  'sending': 0.0,
#  'disenfranchised': 0.0,
#  'line': 0.0,
#  'overinsentivize': 0.0,
#  'unemployment': 0.0,
#  'afternoonevening': 0.0,
#  'completion': 0.0,
#  'sexed': 0.0,
#  'voice': 0.0,
#  'indication': 0.0,
#  'afternoons': 0.0,
#  '31': 0.0,
#  'stronger': 0.0,
#  'rely': 0.0,
#  'peter': 0.0,
#  'spending': 0.0,
#  'dove”': 0.0,
#  'clip': 0.0,
#  'premed': 0.0,
#  'maximization': 0.0,
#  'apply': 0.0,
#  'some': 0.0,
#  'grocery': 0.0,
#  'talented': 0.0,
#  'allman': 0.0,
#  'asthma': 0.0,
#  'yup': 0.0,
#  'baltimore': 0.015873015873015872,
#  'becomes': 0.0,
#  'ignorantly': 0.0,
#  'diseases': 0.0,
#  'victim': 0.0,
#  'definitively': 0.0,
#  'transitioning': 0.0,
#  'accountable': 0.0,
#  'meaningful': 0.0,
#  'that👏🏾': 0.0,
#  'wider': 0.0,
#  '26': 0.0,
#  'contribute': 0.0,
#  'sometime': 0.015873015873015872,
#  'rather': 0.0,
#  'interests': 0.0,
#  'reaching': 0.0,
#  'ms': 0.0,
#  'telling': 0.0,
#  '‘brief’': 0.0,
#  'however': 0.0,
#  '16th': 0.0,
#  'lot': 0.0,
#  'vibe': 0.0,
#  'seventh': 0.0,
#  'toppings': 0.0,
#  'facts': 0.0,
#  'particulars': 0.0,
#  'ever': 0.0,
#  'decide': 0.0,
#  '“the': 0.0,
#  'opportunities\xa0': 0.0,
#  'close': 0.0,
#  'theater': 0.0,
#  'number': 0.0,
#  '\n∧＿∧': 0.0,
#  'directory': 0.0,
#  'twists': 0.0,
#  'communities': 0.0,
#  'defined': 0.0,
#  'program': 0.0,
#  'end': 0.0,
#  'procrastinate': 0.0,
#  'entirely': 0.0,
#  'pimlico': 0.0,
#  'mildly': 0.0,
#  '6th': 0.0,
#  'rebecca': 0.0,
#  'cry': 0.0,
#  '615': 0.0,
#  'obviously': 0.0,
#  'nowm': 0.0,
#  'young': 0.0,
#  'google': 0.0,
#  'viewing': 0.0,
#  'scholars': 0.0,
#  'plants': 0.0,
#  'accident': 0.0,
#  'applied': 0.0,
#  'yaaa': 0.0,
#  'cat”': 0.0,
#  'numbers': 0.0,
#  'attend': 0.0,
#  'nobody': 0.0,
#  'meetings': 0.0,
#  'year': 0.0,
#  'judge': 0.0,
#  'families': 0.0,
#  'gotta': 0.0,
#  'messages': 0.0,
#  'chronic': 0.0,
#  'said': 0.015873015873015872,
#  'say': 0.0,
#  'department': 0.0,
#  'wordnh': 0.0,
#  'she': 0.0,
#  'hi': 0.0,
#  'conflict': 0.0,
#  'fit': 0.0,
#  'meetup': 0.0,
#  'brenner': 0.0,
#  'program\nhow': 0.0,
#  'play': 0.0,
#  'httpwwwbbccouknewsworlduscanada45749891\nthis': 0.0,
#  'tiny': 0.0,
#  'rey': 0.0,
#  'exam': 0.0,
#  'fix': 0.0,
#  'belcher': 0.0,
#  'proceed': 0.0,
#  'apparently': 0.0,
#  'tho': 0.0,
#  'samyukta': 0.0,
#  'heyy': 0.0,
#  'cringey': 0.0,
#  'objective': 0.0,
#  'ed': 0.0,
#  'calcs': 0.0,
#  'different': 0.0,
#  'httpsgristfileswordpresscom201008baltimorecityfoodpolicytaskforcereportpdf': 0.0,
#  'september': 0.0,
#  'go': 0.0,
#  'debate': 0.0,
#  'happen': 0.0,
#  'visiting': 0.0,
#  'mon': 0.0,
#  'incentiveway': 0.0,
#  'lacking': 0.0,
#  'morgan': 0.0,
#  'baltimorian': 0.0,
#  'prize': 0.0,
#  'meetchat': 0.0,
#  'which': 0.0,
#  'comparable': 0.0,
#  'pain': 0.0,
#  'laugh': 0.0,
#  'you’re': 0.0,
#  '😢': 0.0,
#  'won': 0.0,
#  'fleshed': 0.0,
#  'julias': 0.0,
#  'shrink': 0.0,
#  'potentially': 0.0,
#  'chart': 0.0,
#  'acknowledgement': 0.0,
#  'critique': 0.0,
#  'street': 0.0,
#  'again': 0.0,
#  'seems': 0.0,
#  'sentances': 0.0,
#  'idc': 0.0,
#  'produce': 0.0,
#  'overreaching': 0.0,
#  'daun': 0.0,
#  'nonperishable': 0.0,
#  'confused': 0.0,
#  'crack': 0.0,
#  'nobodys': 0.0,
#  'impressive': 0.0,
#  'routewhosenamechanged': 0.0,
#  'opinions': 0.0,
#  'finishing': 0.0,
#  'believe': 0.0,
#  'answered': 0.0,
#  'reminders': 0.0,
#  'everywhere': 0.0,
#  'announced': 0.0,
#  'market': 0.0,
#  'unmute': 0.0,
#  'showing': 0.0,
#  'httpswwwwhen2meetcom7607008zo7av\n': 0.0,
#  'opens': 0.0,
#  'thursday': 0.0,
#  'medina': 0.0,
#  'bell’s': 0.0,
#  '275': 0.0,
#  'wifi': 0.0,
#  'generate': 0.0,
#  'days\n\nyou': 0.0,
#  'veto': 0.0,
#  'they’ll': 0.0,
#  'pages': 0.0,
#  'overachievers': 0.0,
#  'impact': 0.0,
#  'uh': 0.0,
#  'box': 0.0,
#  'raise': 0.0,
#  'swathi': 0.0,
#  '1416': 0.0,
#  'sooner': 0.0,
#  'swim': 0.0,
#  'engaging': 0.0,
#  'winging': 0.0,
#  'superheroes': 0.0,
#  '\n\nstatistic': 0.0,
#  'sign': 0.015873015873015872,
#  'mail': 0.0,
#  'answering': 0.0,
#  'yeahh': 0.0,
#  'prompt': 0.0,
#  'everybody': 0.0,
#  'standards': 0.0,
#  'suspended': 0.0,
#  'responding': 0.0,
#  '1130130': 0.0,
#  'ranting': 0.0,
#  'educating': 0.0,
#  'healthy': 0.0,
#  'summarized': 0.0,
#  '😞': 0.0,
#  'obstacle': 0.0,
#  'mentor': 0.0,
#  'growth': 0.0,
#  'karan': 0.0,
#  'stove': 0.0,
#  'claiming': 0.0,
#  'brainstorming': 0.0,
#  'judgment': 0.0,
#  '1000': 0.0,
#  'leaders': 0.0,
#  'respond': 0.0,
#  'implying': 0.0,
#  'regards': 0.0,
#  'defines': 0.0,
#  'style': 0.0,
#  'matter': 0.0,
#  'sustained': 0.0,
#  'soonish': 0.0,
#  'cabinets': 0.0,
#  'drop': 0.0,
#  'rock': 0.0,
#  'ノ': 0.0,
#  'interrupt': 0.0,
#  'spot': 0.0,
#  'ice': 0.0,
#  'baby': 0.0,
#  'distance': 0.0,
#  'budgetingget': 0.0,
#  'shannon': 0.0,
#  'president': 0.0,
#  'putting': 0.0,
#  'crowded\nex': 0.0,
#  'meh': 0.0,
#  '29th': 0.0,
#  'uber': 0.0,
#  'honestly': 0.0,
#  'musgrove': 0.0,
#  'dozens': 0.0,
#  'considered': 0.0,
#  '1010': 0.0,
#  'pulled': 0.0,
#  'finalize': 0.0,
#  'fare': 0.0,
#  'supplied': 0.0,
#  'phoneslaptop': 0.0,
#  '😆': 0.0,
#  'schoolcollege': 0.0,
#  'ride': 0.0,
#  'panic': 0.0,
#  'closed': 0.0,
#  'downstairs': 0.0,
#  'was': 0.0,
#  'fundraise': 0.0,
#  '71\xa0': 0.0,
#  'team\nreminder': 0.0,
#  'meanings': 0.0,
#  '1150': 0.0,
#  'signup': 0.0,
#  'sue': 0.0,
#  'besides': 0.0,
#  'slightly': 0.0,
#  'diminish': 0.0,
#  'blurp': 0.0,
#  'plausible': 0.0,
#  'winner': 0.0,
#  'bates': 0.0,
#  'respect': 0.0,
#  'awesome': 0.0,
#  'meas': 0.0,
#  'stretch': 0.0,
#  'potter': 0.0,
#  'eye': 0.0,
#  'wrapped': 0.0,
#  'tmrw': 0.0,
#  'maximum': 0.0,
#  '34pm': 0.0,
#  'convenient': 0.0,
#  'messaged': 0.0,
#  'middle': 0.0,
#  'philanthropic': 0.0,
#  'pieces': 0.0,
#  'trust': 0.0,
#  'break😆': 0.0,
#  'tried': 0.0,
#  'coach': 0.0,
#  'serious': 0.0,
#  'tax': 0.0,
#  'characterstics': 0.0,
#  'professor': 0.0,
#  'httpswwwcdcgovpcdissues2012110222htm': 0.0,
#  'nighter': 0.0,
#  'u': 0.0,
#  'nj': 0.0,
#  '6101': 0.0,
#  'wondering': 0.0,
#  '♥️': 0.0,
#  'turned': 0.0,
#  'httpsdocsgooglecomdocumentd16c4jyjnsbcqidxar9b28bakwccln0yb9x8z4wuwr34edituspsharing': 0.0,
#  '“fuck': 0.0,
#  'various': 0.0,
#  'living': 0.0,
#  'appointment': 0.0,
#  'jst': 0.0,
#  'clothes': 0.0,
#  'im': 0.0,
#  'drag': 0.0,
#  'increasing': 0.0,
#  'cheasapeake': 0.0,
#  'cooperation': 0.0,
#  'probs': 0.0,
#  'length': 0.0,
#  'hoco': 0.0,
#  'impulse”': 0.0,
#  'charra': 0.0,
#  '\nduring': 0.0,
#  'movies': 0.0,
#  'vegetarianveganlactose': 0.0,
#  'therefore': 0.0,
#  'approaches': 0.0,
#  'section': 0.0,
#  'flaw': 0.0,
#  'placement': 0.0,
#  'fuck': 0.0,
#  'hes': 0.0,
#  'amendment': 0.0,
#  'define': 0.0,
#  'subculture': 0.0,
#  'soo': 0.0,
#  'black': 0.0,
#  'homeless': 0.0,
#  'hear': 0.0,
#  'temperature': 0.0,
#  'abt': 0.0,
#  'school\nben': 0.0,
#  'throw': 0.0,
#  'pressure': 0.0,
#  'slight': 0.0,
#  'forever': 0.0,
#  'swimmers': 0.0,
#  'setting': 0.0,
#  '“5': 0.0,
#  'evening': 0.0,
#  'that’s': 0.0,
#  'kchong2umbcedu': 0.0,
#  'completely': 0.0,
#  '4': 0.0,
#  'here’s': 0.0,
#  'helps': 0.0,
#  'same': 0.0,
#  'logged': 0.0,
#  'compiled': 0.0,
#  'swear': 0.0,
#  'it😇': 0.0,
#  'input': 0.0,
#  '23': 0.0,
#  'enjoyed': 0.0,
#  'laptops': 0.0,
#  'orioles': 0.0,
#  'deleted': 0.0,
#  'part\n3': 0.0,
#  'interdisciplinary': 0.0,
#  '😎': 0.0,
#  'school': 0.0,
#  'reliable': 0.0,
#  '☹': 0.0,
#  'tiebreaker': 0.0,
#  'individualbased': 0.0,
#  'speaking': 0.0,
#  'it”': 0.0,
#  'meantime': 0.0,
#  'environments': 0.0,
#  'operators': 0.0,
#  'hop': 0.0,
#  'transportation': 0.0,
#  'interested': 0.0,
#  '215530': 0.0,
#  'refurbishment': 0.0,
#  'deals': 0.0,
#  'alright': 0.0,
#  'incentives': 0.0,
#  'bit”': 0.0,
#  'in\xa0': 0.0,
#  'grade': 0.0,
#  'excellence': 0.0,
#  'poor': 0.0,
#  'thirty': 0.0,
#  'drivers': 0.0,
#  'facet': 0.0,
#  'ups': 0.0,
#  'vegan': 0.0,
#  'via': 0.0,
#  'welcome': 0.0,
#  '1210': 0.0,
#  'nic': 0.0,
#  'idea': 0.0,
#  'ideally': 0.0,
#  'missing': 0.0,
#  'shortly': 0.0,
#  'tied': 0.0,
#  'surveys': 0.0,
#  'lowkey': 0.0,
#  'pdf': 0.0,
#  'up\n\ngetting': 0.0,
#  'tonight': 0.0,
#  'commitment—to': 0.0,
#  'join\n\nhttpsgroupmecomjoingroup45563234qjc2pk': 0.0,
#  'fast': 0.0,
#  '3pm': 0.0,
#  'brigade': 0.0,
#  'counselor': 0.0,
#  'agenda': 0.0,
#  'warrant': 0.0,
#  'commitments': 0.0,
#  'trucklobbying': 0.0,
#  '515': 0.0,
#  'pasted': 0.0,
#  'commuting': 0.0,
#  'join': 0.0,
#  'social': 0.0,
#  'ahead': 0.0,
#  'research': 0.0,
#  'timewhere': 0.0,
#  'oconnor': 0.0,
#  'qualifications': 0.0,
#  'way': 0.0,
#  'states': 0.0,
#  'stay': 0.0,
#  'treating': 0.0,
#  'desert”': 0.0,
#  'logic': 0.0,
#  'rescheduled': 0.0,
#  'scheduling': 0.0,
#  'erin°': 0.0,
#  'facing': 0.0,
#  '111': 0.0,
#  'orion': 0.0,
#  'dust': 0.0,
#  '220': 0.0,
#  'assistance': 0.0,
#  'toc': 0.0,
#  'topic': 0.0,
#  'judges’': 0.0,
#  'able': 0.0,
#  '9th': 0.0,
#  'the': 0.047619047619047616,
#  'niw': 0.0,
#  'comment': 0.0,
#  'james': 0.0,
#  'audience': 0.0,
#  'spoken': 0.0,
#  '4730': 0.0,
#  'medicaid': 0.0,
#  'offic': 0.0,
#  '\nwe': 0.0,
#  'motivation': 0.0,
#  'proposed': 0.0,
#  'outcome': 0.0,
#  '205': 0.0,
#  'amd': 0.0,
#  'pickup': 0.0,
#  'speech': 0.0,
#  'useful': 0.0,
#  'theo': 0.0,
#  'assist': 0.0,
#  'pins': 0.0,
#  'starting': 0.0,
#  'funding': 0.0,
#  '100': 0.0,
#  'restrictions': 0.0,
#  'valid': 0.0,
#  'reserved': 0.0,
#  'wordy': 0.0,
#  'stats': 0.0,
#  'miss': 0.0,
#  '7th': 0.0,
#  'corrected': 0.0,
#  'ches': 0.0,
#  '1159pm': 0.0,
#  'brigades': 0.0,
#  '👍🏻': 0.0,
#  'youve': 0.0,
#  'gillian': 0.0,
#  'guessed': 0.0,
#  'poll': 0.0,
#  'tbh': 0.0,
#  'succeed': 0.0,
#  'donated': 0.0,
#  'blueprintwhat’s': 0.0,
#  'deal': 0.0,
#  'bon': 0.0,
#  'apron': 0.0,
#  'stupid': 0.0,
#  'later\n\nhaving': 0.0,
#  'seattle': 0.0,
#  'essays': 0.0,
#  'second': 0.0,
#  'eat': 0.0,
#  'accounts': 0.0,
#  'essentially': 0.0,
#  'inclusion': 0.0,
#  'teaches': 0.0,
#  'blueprint': 0.0,
#  'rationale': 0.0,
#  'growing': 0.0,
#  'dollars': 0.0,
#  'bonjour': 0.0,
#  'picky': 0.0,
#  'difficulty': 0.0,
#  'launch': 0.0,
#  'm': 0.0,
#  'routine': 0.0,
#  'mile': 0.0,
#  'ethics': 0.0,
#  'wind': 0.0,
#  'jumping': 0.0,
#  'provides': 0.0,
#  'actually': 0.015873015873015872,
#  'deadlines': 0.0,
#  'httpssgroupmecomcpcotye': 0.0,
#  'transit': 0.0,
#  'images': 0.0,
#  'disease': 0.0,
#  'can': 0.015873015873015872,
#  '2430': 0.0,
#  'policy': 0.0,
#  'smcnary1umbcedu': 0.0,
#  'create': 0.0,
#  'many': 0.0,
#  'they’re': 0.0,
#  'follows': 0.0,
#  'inform': 0.0,
#  'crank': 0.0,
#  'garnett': 0.0,
#  'whoever’s': 0.0,
#  'improving': 0.0,
#  'dhall': 0.0,
#  'owens': 0.0,
#  'alcohol': 0.0,
#  'provide': 0.0,
#  'must': 0.0,
#  'cannot': 0.0,
#  'side': 0.0,
#  'identical': 0.0,
#  'passes': 0.0,
#  'choice': 0.0,
#  'closing': 0.0,
#  'dc': 0.0,
#  'lunches': 0.0,
#  'skinny': 0.0,
#  'compilation': 0.0,
#  'graduate': 0.0,
#  'whoever': 0.0,
#  'feasible': 0.0,
#  'longue': 0.0,
#  'lactoseintolerant': 0.0,
#  'first': 0.0,
#  'k’s': 0.0,
#  'homes': 0.0,
#  'impactful': 0.0,
#  'working': 0.0,
#  'cares': 0.0,
#  'reserving': 0.0,
#  'midnight': 0.0,
#  'highschool': 0.0,
#  'limit': 0.0,
#  'easy': 0.0,
#  'interview': 0.0,
#  'tangible': 0.0,
#  'regroup': 0.0,
#  'problem': 0.0,
#  'apartment': 0.0,
#  'team\nsorry': 0.0,
#  'vp': 0.0,
#  ...}

# %%
df_word_frequencies = pd.DataFrame(word_dict_tf)
df_word_frequencies.to_excel(tfidf_path+"FA18_word_frequency_vectors.xlsx")

# %%
# Compute inverse data frequency
def computeIDF(documents):
    import math
    N = len(documents)
    
    idfDict = dict.fromkeys(documents[0].keys(), 0)
    for document in documents:
        for word, val in document.items():
            if val > 0:
                idfDict[word] += 1
    
    for word, val in idfDict.items():
        idfDict[word] = math.log(N / float(val))
    return idfDict

# %%
idfs = computeIDF(word_dicts)

# %%
# Computes tf x idf
def computeTFIDF(tfBagOfWords, idfs):
    tfidf = {}
    for word, val in tfBagOfWords.items():
        tfidf[word] = val * idfs[word]
    return tfidf

# %%
word_dict_tfidfs = []
for index, row in df_fall_18_messages.iterrows():
    word_dict_tfidfs.append(computeTFIDF(word_dict_tf[index], idfs))

# %%
df_word_tfidfs = pd.DataFrame(word_dict_tfidfs)

# %%
df_word_tfidfs.to_excel(tfidf_path+"FA18_tfidf_vectors.xlsx")
